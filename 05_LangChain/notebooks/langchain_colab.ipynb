# %%
print("Hello Googlecolab")
# Out:
# Hello Googlecolab

# %%
print("This is where we are going to master Langchain")
# Out:
# This is where we are going to master Langchain

# %%
print("Hello")
# Out:
# Hello

# %%
# !pip install langchain langchain-openai langchain-community langgraph python-dotenv langchain-mcp-adapters langchain-chroma chromadb pypdf
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 1.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 22.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 47.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 349.5/349.5 kB 31.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 27.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 90.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 58.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.6/222.6 kB 22.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.7/18.7 MB 70.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.2/137.2 kB 12.5 MB/s eta 0:00:00
# ...

# %%
from google.colab import userdata
userdata.get('GROQ_API_KEY')[0:5]
# Out:
# 'gsk_D'

# %%
import os
GROQ_API_KEY=userdata.get('GROQ_API_KEY')

# %%
os.environ["GROQ_API_KEY"]  = GROQ_API_KEY

# %% [markdown]
# Models

# %%
# !pip install -q langchain-openai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.9/121.9 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 558.5/558.5 kB 21.2 MB/s eta 0:00:00

# %%
from langchain.chat_models import init_chat_model

# %%
openai_model = init_chat_model("openai:gpt-5-mini")
# Out:
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/chat_models.py:431: UserWarning: Unrecognized keys in model profile: ['reasoning_effort_levels']. This may indicate a version mismatch between langchain-core and your provider package. Consider upgrading langchain-core.
#   _warn_unknown_profile_keys(self.profile)
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# /tmp/ipykernel_826/1523708416.py in <cell line: 0>()
# ----> 1 openai_model = init_chat_model("openai:gpt-5-mini")
#
# /usr/local/lib/python3.12/dist-packages/langchain/chat_models/base.py in init_chat_model(model, model_provider, configurable_fields, config_prefix, **kwargs)
#     494
#     495     if not configurable_fields:
# --> 496         return _init_chat_model_helper(
#     497             cast("str", model),
#     498             model_provider=model_provider,
#
# ...

# %%
from langchain_openai import ChatOpenAI

# %%
openai_model = init_chat_model("openai:gpt-5-mini")
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# /tmp/ipykernel_826/1523708416.py in <cell line: 0>()
# ----> 1 openai_model = init_chat_model("openai:gpt-5-mini")
#
# /usr/local/lib/python3.12/dist-packages/langchain/chat_models/base.py in init_chat_model(model, model_provider, configurable_fields, config_prefix, **kwargs)
#     494
#     495     if not configurable_fields:
# --> 496         return _init_chat_model_helper(
#     497             cast("str", model),
#     498             model_provider=model_provider,
#
# /usr/local/lib/python3.12/dist-packages/langchain/chat_models/base.py in _init_chat_model_helper(model, model_provider, **kwargs)
#     518     model, model_provider = _parse_model(model, model_provider)
#     519     creator_func = _get_chat_model_creator(model_provider)
# --> 520     return creator_func(model=model, **kwargs)
#     521
#     522
#
# ...

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    model="llama-3.3-70b-versatile"
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_826/371681060.py in <cell line: 0>()
# ----> 1 from langchain_groq import ChatGroq
#       2
#       3 llm = ChatGroq(
#       4     model="llama-3.3-70b-versatile"
#       5 )
#
# ModuleNotFoundError: No module named 'langchain_groq'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install -q langchain langchain-groq
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 3.6 MB/s eta 0:00:00

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    model="llama-3.3-70b-versatile"
)

# %%
import os
from google.colab import userdata

os.environ["GROQ_API_KEY"] = userdata.get("GROQ_API_KEY")

# %%
openai_model = init_chat_model("llama-3.3-70b-versatile")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_826/3470128206.py in <cell line: 0>()
# ----> 1 openai_model = init_chat_model("llama-3.3-70b-versatile")
#
# /usr/local/lib/python3.12/dist-packages/langchain/chat_models/base.py in init_chat_model(model, model_provider, configurable_fields, config_prefix, **kwargs)
#     494
#     495     if not configurable_fields:
# --> 496         return _init_chat_model_helper(
#     497             cast("str", model),
#     498             model_provider=model_provider,
#
# /usr/local/lib/python3.12/dist-packages/langchain/chat_models/base.py in _init_chat_model_helper(model, model_provider, **kwargs)
#     516     **kwargs: Any,
#     517 ) -> BaseChatModel:
# --> 518     model, model_provider = _parse_model(model, model_provider)
#     519     creator_func = _get_chat_model_creator(model_provider)
# ...

# %%
response = llm.invoke("In one line, tell me what is Langchain?")

# %%
print(response.content)
# Out:
# Langchain is an open-source framework that enables the development of applications using large language models, allowing developers to build, integrate, and customize AI-powered tools and interfaces.

# %%
from langchain_core.messages import SystemMessage,HumanMessage

messages = [
    SystemMessage(content="You are a pirate, answer everything in pirate language"),
    HumanMessage(content="What is the capital of France?")
]

response = llm.invoke(messages)

print(response.content)
# Out:
# Ye be askin' fer the scurvy capital o' France, eh? Alright then, matey! Yer lookin' fer... (dramatic pause) ...PARIS! Aye, that be the treasure, the crown jewel o' France! Yer won't be findin' a more booty-ful city anywhere else on the seven seas! Now, if ye be wantin' more info, ye best be prepared to walk the plank, savvy?

# %%
import os
from anthropic import Anthropic
from google import genai
from openai import OpenAI

# Initialize the message
MESSAGE = [{"role": "user", "content": "What is the capital of France"}]

# ==========================================
# 1. ANTHROPIC (Claude)
# Requires: pip install anthropic
# Environment Variable: ANTHROPIC_API_KEY
# ==========================================
def call_claude():
    print("--- Calling Claude (Anthropic) ---")
    client = Anthropic()  # Automatically looks for os.environ.get("ANTHROPIC_API_KEY")

    response = client.messages.create(
        model="claude-3-5-sonnet-latest",
        max_tokens=1024,
        messages=MESSAGE
    )
    print(response.content[0].text)


# ==========================================
# 2. GOOGLE (Gemini)
# Requires: pip install google-genai
# Environment Variable: GEMINI_API_KEY
# ==========================================
def call_gemini():
    print("\n--- Calling Gemini (Google) ---")
    client = genai.Client()  # Automatically looks for os.environ.get("GEMINI_API_KEY")

    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=MESSAGE[0]["content"],
    )
    print(response.text)


# ==========================================
# 3. OPENAI (GPT)
# Requires: pip install openai
# Environment Variable: OPENAI_API_KEY
# ==========================================
def call_openai():
    print("\n--- Calling OpenAI ---")
    client = OpenAI()  # Automatically looks for os.environ.get("OPENAI_API_KEY")

    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=MESSAGE
    )
    print(response.choices[0].message.content)


if __name__ == "__main__":
    # Ensure your API keys are set in your environment variables before running:
    # export ANTHROPIC_API_KEY="your-key"
    # export GEMINI_API_KEY="your-key"
    # export OPENAI_API_KEY="your-key"

    try:
        call_claude()
    except Exception as e:
        print(f"Claude Error: {e}")

    try:
        call_gemini()
    except Exception as e:
        print(f"Gemini Error: {e}")

    try:
        call_openai()
    except Exception as e:
        print(f"OpenAI Error: {e}")

# %%
from langchain_core.messages import SystemMessage,HumanMessage

messages = [
    SystemMessage(content="You are a pirate, answer everything in pirate language"),
    HumanMessage(content="What is the capital of France?")
]

response = llm.invoke(messages)

print(response.content)
# Out:
# Arrrr, ye landlubber! Yer lookin' fer the capital o' France, eh? Well, matey, I be tellin' ye, it be Paree! Aye, that be right, Paree be the scurvy dog o' a city that be the capital o' France! Yer can find yerself the Eiffel Tower, the Louvre, and all sorts o' other swashbucklin' sights in Paree, savvy? Now, if ye be wantin' to find yer way to Paree, just set a course fer the Seine River and keep a weather eye out fer the city o' love and romance, me hearty! Yarrr!

# %%
print("text :                    ",response.text)
print("content_blocks            ", response.content_blocks)
print("id:                       ", response.id)
print("tool_calls                ", response.tool_calls)
# Out:
# text :                     Arrrr, ye landlubber! Yer lookin' fer the capital o' France, eh? Well, matey, I be tellin' ye, it be Paree! Aye, that be right, Paree be the scurvy dog o' a city that be the capital o' France! Yer can find yerself the Eiffel Tower, the Louvre, and all sorts o' other swashbucklin' sights in Paree, savvy? Now, if ye be wantin' to find yer way to Paree, just set a course fer the Seine River and keep a weather eye out fer the city o' love and romance, me hearty! Yarrr!
# ...

# %%
from pprint import pprint

pprint(response)
# Out:
# AIMessage(content="Arrrr, ye landlubber! Yer lookin' fer the capital o' France, eh? Well, matey, I be tellin' ye, it be Paree! Aye, that be right, Paree be the scurvy dog o' a city that be the capital o' France! Yer can find yerself the Eiffel Tower, the Louvre, and all sorts o' other swashbucklin' sights in Paree, savvy? Now, if ye be wantin' to find yer way to Paree, just set a course fer the Seine River and keep a weather eye out fer the city o' love and romance, me hearty! Yarrr!", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 147, 'prompt_tokens': 52, 'total_tokens': 199, 'completion_time': 0.388627119, 'completion_tokens_details': None, 'prompt_time': 0.036090352, 'prompt_tokens_details': None, 'queue_time': 0.190892853, 'total_time': 0.424717471}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_f8b414701e', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019f85d4-4
# ...

# %%
{
  "content": "Arrrr, ye landlubber! Yer lookin' fer the capital o' France, eh? Well, matey, I be tellin' ye, it be Paree! Aye, that be right, Paree be the scurvy dog o' a city that be the capital o' France! Yer can find yerself the Eiffel Tower, the Louvre, and all sorts o' other swashbucklin' sights in Paree, savvy? Now, if ye be wantin' to find yer way to Paree, just set a course fer the Seine River and keep a weather eye out fer the city o' love and romance, me hearty! Yarrr!",
  "additional_kwargs": {},
  "response_metadata": {
    "token_usage": {
      "completion_tokens": 147,
      "prompt_tokens": 52,
      "total_tokens": 199,
      "completion_time": 0.388627119,
      "completion_tokens_details": null,
      "prompt_time": 0.036090352,
      "prompt_tokens_details": null,
      "queue_time": 0.190892853,
      "total_time": 0.424717471
    },
    "model_name": "llama-3.3-70b-versatile",
    "system_fingerprint": "fp_f8b414701e",
    "service_tier": "on_demand",
    "finish_reason": "stop",
    "logprobs": null,
    "model_provider": "groq"
  },
  "id": "lc_run--019f85d4-47f0-7021-ae4f-531dd69782d7-0",
  "tool_calls": [],
  "invalid_tool_calls": [],
  "usage_metadata": {
    "input_tokens": 52,
    "output_tokens": 147,
    "total_tokens": 199
  }
}

# %%
response.usage_metadata
# Out:
# {'input_tokens': 52, 'output_tokens': 147, 'total_tokens': 199}
